# %% [markdown]
# <a href="https://colab.research.google.com/github/TomaszWlo/learning-git-task/blob/master/10_3_zadanie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.preprocessing import StandardScaler, MinMaxScaler

np.random.seed(42)

data_100 = np.random.normal(loc=3, scale=1, size=100)
data_10000 = np.random.normal(loc=3, scale=1, size=10000)

# %%
# Zbiór 100

median_100 = np.median(data_100)
mode_100 = stats.mode(data_100)
max_100 = np.max(data_100)
min_100 = np.min(data_100)
q1_100 = np.quantile(data_100, 0.25)
q3_100 = np.quantile(data_100, 0.75)

print(f'Mediana {median_100}')
print(f'Moda {mode_100}')
print(f'Max {max_100}')
print(f'Min {min_100}')
print(f'Kwartyl Q1 {q1_100}')
print(f'Kwartyl Q3 {q3_100}')
# Out:
# Mediana 2.8730437082202873
# Moda ModeResult(mode=np.float64(0.38025489591025563), count=np.int64(1))
# Max 4.852278184508938
# Min 0.38025489591025563
# Kwartyl Q1 2.399094329503547
# Kwartyl Q3 3.4059520520120623

# %% [markdown]
# Wnioski ze zbioru liczb do 100:
# Mediana tego zbioru wynosi 2,87
# Moda kazda wartosc w zbiorze wysteuje tylko raz nic sie nie powtarza
# Maksymalna liczba ze zbioru to 4,85
# Minimalna liczba ze zboru to 0,38
# Kwartyl Q1 wynosi 2,4 a
# kwartyl Q4 3.4

# %%
# Zbiór 10 000

median_10000 = np.median(data_10000)
mode_10000 = stats.mode(data_10000)
max_10000 = np.max(data_10000)
min_10000 = np.min(data_10000)
q1_10000 = np.quantile(data_10000, 0.25)
q3_10000 = np.quantile(data_10000, 0.75)

print(f'Mediana {median_10000}')
print(f'Moda {mode_10000}')
print(f'Max {max_10000}')
print(f'Min {min_10000}')
print(f'Kwartyl Q1 {q1_10000}')
print(f'Kwartyl Q3 {q3_10000}')
# Out:
# Mediana 2.998834844229987
# Moda ModeResult(mode=np.float64(-0.9224002516183423), count=np.int64(1))
# Max 6.926237706436327
# Min -0.9224002516183423
# Kwartyl Q1 2.3264345054022297
# Kwartyl Q3 3.6720318078709733

# %% [markdown]
# Wnioski ze zbioru liczb do 10 000:
# Mediana tego zbioru wynosi prawie 3
# Moda kazda wartosc w zbiorze wysteuje tylko raz nic sie nie powtarza
# Maksymalna liczba ze zbioru to 6,9
# Minimalna liczba ze zboru to - 0,9
# Kwartyl Q1 wynosi 2,3
# kwartyl Q4 3,7
