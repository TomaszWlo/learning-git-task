# %% [markdown]
# <a href="https://colab.research.google.com/github/TomaszWlo/learning-git-task/blob/master/zadanie_8_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Ponizej zrobione zostaly punkty z zadania od 1 - 3

# %%
import pandas as pd

album = pd.read_html('https://www.officialcharts.com/chart-news/the-best-selling-albums-of-all-time-on-the-official-uk-chart__15551/', header=0)
df = album[0]

df.rename(columns={'TITLE':'TYTUŁ', "ARTIST":'ARTYSTA', 'YEAR':'ROK', 'HIGH POSN':'MAX POZ'}, inplace=True)
print(df.columns)

df['ARTYSTA'].unique()
df['ARTYSTA'].nunique()
df['ARTYSTA'].value_counts()
# Out:
# Index(['POS', 'TYTUŁ', 'ARTYSTA', 'ROK', 'MAX POZ'], dtype='object')
# ARTYSTA
# TAKE THAT                   3
# COLDPLAY                    3
# QUEEN                       2
# ADELE                       2
# MICHAEL JACKSON             2
# ABBA                        2
# BEATLES                     2
# DIDO                        2
# ORIGINAL SOUNDTRACK         2
# FLEETWOOD MAC               2
# ROBBIE WILLIAMS             2
# PINK FLOYD                  1
# DIRE STRAITS                1
# MADONNA                     1
# OASIS                       1
# JAMES BLUNT                 1
# BOB MARLEY & THE WAILERS    1
# SHANIA TWAIN                1
# SIMPLY RED                  1
# AMY WINEHOUSE               1
# SIMON & GARFUNKEL           1
# MEAT LOAF                   1
# LEONA LEWIS                 1
# DAVID GRAY                  1
# MICHAEL BUBLE               1
# SPICE GIRLS                 1
# CORRS                       1
# LADY GAGA                   1
# ...

# %% [markdown]
# 2. Poniżej zrobilem punkty od 4 - 6

# %%
import pandas as pd

album = pd.read_html('https://www.officialcharts.com/chart-news/the-best-selling-albums-of-all-time-on-the-official-uk-chart__15551/', header=0)
df = album[0]

df.rename(columns={'TITLE':'TYTUŁ', "ARTIST":'ARTYSTA', 'YEAR':'ROK', 'HIGH POSN':'MAX POZ'}, inplace=True)
print(df.columns)

df.columns = df.columns.str.capitalize()
print(df.columns)

df.drop('Max poz', axis=1, inplace=True)
print(df.columns)


df['Rok'].value_counts()
# Out:
# Index(['POS', 'TYTUŁ', 'ARTYSTA', 'ROK', 'MAX POZ'], dtype='object')
# Index(['Pos', 'Tytuł', 'Artysta', 'Rok', 'Max poz'], dtype='object')
# Index(['Pos', 'Tytuł', 'Artysta', 'Rok'], dtype='object')
# Rok
# 1987    4
# 2000    4
# 2006    3
# 1977    3
# 1998    3
# 1997    3
# 2004    3
# 1991    2
# 1995    2
# 1992    2
# 2005    2
# 2008    2
# 1973    2
# 2002    2
# 2011    1
# 1981    1
# 1967    1
# 1984    1
# 1990    1
# 1982    1
# 1985    1
# 2009    1
# 2007    1
# 1970    1
# 1996    1
# 2015    1
# 2003    1
# 1978    1
# 1989    1
# 1999    1
# 1988    1
# 1975    1
# 2014    1
# 1986    1
# 1965    1
# 2001    1
# 2010    1
# Name: count, dtype: int64

# %% [markdown]
# 3. Poniżej zrobilem punkt 7
#
# ---

# %%
import pandas as pd

album = pd.read_html('https://www.officialcharts.com/chart-news/the-best-selling-albums-of-all-time-on-the-official-uk-chart__15551/', header=0)
df = album[0]

df.rename(columns={'TITLE':'TYTUŁ', "ARTIST":'ARTYSTA', 'YEAR':'ROK', 'HIGH POSN':'MAX POZ'}, inplace=True)
print(df.columns)

df.columns = df.columns.str.capitalize()
print(df.columns)

df.drop('Max poz', axis=1, inplace=True)
print(df.columns)

len(df[(df['Rok']>1960) | (df['Rok'] < 1990)])
# Out:
# Index(['POS', 'TYTUŁ', 'ARTYSTA', 'ROK', 'MAX POZ'], dtype='object')
# Index(['Pos', 'Tytuł', 'Artysta', 'Rok', 'Max poz'], dtype='object')
# Index(['Pos', 'Tytuł', 'Artysta', 'Rok'], dtype='object')
# 60

# %% [markdown]
# 4. Poniżej zrobilem punkt od 8 - 10
#
# ---

# %%
import pandas as pd

album = pd.read_html('https://www.officialcharts.com/chart-news/the-best-selling-albums-of-all-time-on-the-official-uk-chart__15551/', header=0)
df = album[0]

df.rename(columns={'TITLE':'TYTUŁ', "ARTIST":'ARTYSTA', 'YEAR':'ROK', 'HIGH POSN':'MAX POZ'}, inplace=True)
print(df.columns)

df.columns = df.columns.str.capitalize()
print(df.columns)

df.drop('Max poz', axis=1, inplace=True)
print(df.columns)

print(df['Rok'].min())

df.sort_values(by='Rok').to_csv('Sorted table')
# Out:
# Index(['POS', 'TYTUŁ', 'ARTYSTA', 'ROK', 'MAX POZ'], dtype='object')
# Index(['Pos', 'Tytuł', 'Artysta', 'Rok', 'Max poz'], dtype='object')
# Index(['Pos', 'Tytuł', 'Artysta', 'Rok'], dtype='object')
# 1965
#     Pos                                   Tytuł                   Artysta  \
# 51   52                      THE SOUND OF MUSIC   ORIGINAL CAST RECORDING
# 2     3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 20   21              BRIDGE OVER TROUBLED WATER         SIMON & GARFUNKEL
# 6     7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 41   42                           TUBULAR BELLS             MIKE OLDFIELD
# 45   46                           GREATEST HITS                      ABBA
# 18   19                         BAT OUT OF HELL                 MEAT LOAF
# 10   11                                 RUMOURS             FLEETWOOD MAC
# 46   47                                  GREASE       ORIGINAL SOUNDTRACK
# ...
